# %%
import numpy as np
import pandas as pd

# Visualization
import matplotlib.pyplot as plt

# Data processing, modeling, and model evaluation
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score, classification_report, plot_confusion_matrix
from sklearn.tree import DecisionTreeClassifier

#Files
import h5py
import glob
import seaborn as sns

# %%
f=h5py.File(r'features_database_gait_one_cycles_both_legs_jrd_hdf.h5', 'r')
print(list(f.keys()))
x = f['right'][:,:,:]
print('(samples, timesteps, features)', x.shape)
y = f['left'][:,:,:]
print('(samples, timesteps, features)', y.shape)
# Out:
# ['left', 'right']
# (samples, timesteps, features) (74, 132, 4)
# (samples, timesteps, features) (76, 132, 4)

# %%
nsamples, nx, ny = x.shape
d2_x = x.reshape((nsamples,nx*ny))

scaler = StandardScaler()
scaled_data = scaler.fit_transform(d2_x)
scaled_data.shape
# Out:
# (74, 528)

# %%
nsamples, nx, ny = y.shape
d2_x = y.reshape((nsamples,nx*ny))

scaler = StandardScaler()
scaled_data_l = scaler.fit_transform(d2_x)
scaled_data_l.shape
# Out:
# (76, 528)

# %%
pca = PCA(n_components=scaled_data.shape[0], svd_solver='full')
pca.fit(scaled_data)
X_pca = pca.transform(scaled_data)

pca_l = PCA(n_components=scaled_data_l.shape[0], svd_solver='full')
pca_l.fit(scaled_data_l)
X_pca_l = pca_l.transform(scaled_data_l)

# %%
cum_exp_var = []
cum_exp_var_l = []
var_exp = 0
var_exp_l = 0

for i in pca.explained_variance_ratio_:
    var_exp += i
    cum_exp_var.append(var_exp)
    
for k in pca_l.explained_variance_ratio_:
    var_exp_l += k
    cum_exp_var_l.append(var_exp_l)

# %%
# fig, ax = plt.subplots(1, 2, figsize=(16,7))

# ax[0].bar(range(1,75), cum_exp_var)
# ax[0].set_xlabel('Principal Components')
# ax[0].set_ylabel('Cumulative Variance Explained %')
# ax[0].set_title('Right')
# ax[0].axhline(y=1.0, color = 'red', linestyle='--')
# ax[0].axvline(x=10.0, color = 'red', linestyle='--')

# ax[1].bar(range(1,77), cum_exp_var_l)
# ax[1].set_xlabel('Principal Components')
# ax[1].set_ylabel('Cumulative Variance Explained %')
# ax[1].set_title('Left')
# ax[1].axhline(y=1.0, color = 'red', linestyle='--')
# ax[1].axvline(x=10.0, color = 'red', linestyle='--')

# %%
def decision_tree(scaled_data, ran, digits_int):
    from sklearn.metrics import f1_score, classification_report, plot_confusion_matrix
    train_f1 = []
    test_f1 = []

    for i in range(ran):
    
        X = scaled_data[:,0:i+1]
    
        # Train-test-split
        X_train, X_test, y_train, y_test = train_test_split(X, digits_int,
                                                            test_size=0.25,
                                                            random_state=42)

        # Perform feature scaling
        scaler = StandardScaler()
        X_train = scaler.fit_transform(X_train)
        X_test = scaler.transform(X_test)

        dtc = DecisionTreeClassifier()
        dtc.fit(X_train, y_train)
        y_pred_train = dtc.predict(X_train)
        y_pred_test = dtc.predict(X_test)
        train_f1.append(f1_score(y_train, y_pred_train))
        test_f1.append(f1_score(y_test, y_pred_test))
    
    return train_f1, test_f1

# %%
def knn_tree(scaled_data, ran, digits_int):
    from sklearn.metrics import f1_score, classification_report, plot_confusion_matrix
    train_f1 = []
    test_f1 = []

    for i in range(ran):
    
        X = scaled_data[:,0:i+1]
    
        # Train-test-split
        X_train, X_test, y_train, y_test = train_test_split(X, digits_int,
                                                            test_size=0.25,
                                                            random_state=42)

        # Perform feature scaling
        scaler = StandardScaler()
        X_train = scaler.fit_transform(X_train)
        X_test = scaler.transform(X_test)

        knn = KNeighborsClassifier()
        knn.fit(X_train, y_train)
        y_pred_train = knn.predict(X_train)
        y_pred_test = knn.predict(X_test)
        train_f1.append(f1_score(y_train, y_pred_train))
        test_f1.append(f1_score(y_test, y_pred_test))
    
    return train_f1, test_f1

# %%
def digits(path,ran):
    filelist =[]
    digits =[]
    digits_int =[]
    for file in glob.glob(f'{path}\\*.c3d',recursive = True):
        filelist.append(file[4:-4].replace("_", ""))
        digits.append(file[ran:-9])

    for ele in digits:
        digits_int.append(1) if ele=='degeneration' else digits_int.append(0)
    len(digits_int)
    
    return digits_int

# %%
d_r = digits(f'cut_one_gait_cycle_right', 25)
d_l = digits(f'cut_one_gait_cycle_left', 24)
train_l, test_l = decision_tree(X_pca_l, 76, d_l)
train_r, test_r = decision_tree(X_pca, 74, d_r)

# %%
# d_r

# %%
fig, ax = plt.subplots(1, 2, figsize=(16,7))

ax[0].plot(range(1,75), train_r, label='Train f1 Score')
ax[0].plot(range(1,75), test_r, label='Test f1 Score')
ax[0].set_ylabel('f1 Score')
ax[0].set_xlabel('# of Principal Components')
ax[0].axvline(x=24.0,ymax=0.58, color = 'black', linestyle='--')
ax[0].axvline(x=32.0,ymax=0.65, color = 'black', linestyle='--')
ax[0].plot(24.0, 0.84, color='black', marker='o', markersize=5)
ax[0].plot(32.0, 0.87, color='black', marker='o', markersize=5)
ax[0].legend()
ax[0].set_title('Right site')

ax[1].plot(range(1,77), train_l, label='Train f1 Score')
ax[1].plot(range(1,77), test_l, label='Test f1 Score')
ax[1].set_ylabel('f1 Score')
ax[1].set_xlabel('# of Principal Components')
ax[1].axvline(x=2.0,ymax=0.79, color = 'black', linestyle='--')
ax[1].axvline(x=27.0,ymax=0.70, color = 'black', linestyle='--')
ax[1].plot(2.0, 0.91, color='black', marker='o', markersize=5)
ax[1].plot(27.0, 0.85, color='black', marker='o', markersize=5)
ax[1].legend()
ax[1].set_title('Left site')
# Out:
# Text(0.5, 1.0, 'Left site')

# %%
train_l, test_l = knn_tree(X_pca_l, 76, d_l)
train_r, test_r = knn_tree(X_pca, 74, d_r)

# %%
fig, ax = plt.subplots(1, 2, figsize=(16,7))

ax[0].plot(range(1,75), train_r, label='Train f1 Score')
ax[0].plot(range(1,75), test_r, label='Test f1 Score')
ax[0].set_ylabel('f1 Score')
ax[0].set_xlabel('# of Principal Components')
ax[0].axvline(x=1.0,ymax=0.92, color = 'black', linestyle='--')
ax[0].axvline(x=21.0,ymax=0.87, color = 'black', linestyle='--')
ax[0].plot(1.0, 0.88, color='black', marker='o', markersize=5)
ax[0].plot(21.0, 0.84, color='black', marker='o', markersize=5)
ax[0].legend()
ax[0].set_title('Right site')

ax[1].plot(range(1,77), train_l, label='Train f1 Score')
ax[1].plot(range(1,77), test_l, label='Test f1 Score')
ax[1].set_ylabel('f1 Score')
ax[1].set_xlabel('# of Principal Components')
ax[1].axvline(x=7.0,ymax=0.95, color = 'black', linestyle='--')
ax[1].axvline(x=26.0,ymax=0.95, color = 'black', linestyle='--')
ax[1].plot(7.0, 0.88, color='black', marker='o', markersize=5)
ax[1].plot(26.0, 0.88, color='black', marker='o', markersize=5)
ax[1].legend()
ax[1].set_title('Left site')
# Out:
# Text(0.5, 1.0, 'Left site')
