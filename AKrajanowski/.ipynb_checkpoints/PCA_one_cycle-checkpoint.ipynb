# %%
import h5py
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import glob
import seaborn as sns

# %%
f=h5py.File(r'features_database_gait_one_cycles_both_legs.h5', 'r')
print(list(f.keys()))
x = f['right'][:,:,:]
y = f['left'][:,:,:]
print('(samples, timesteps, features)', x.shape)
print('(samples, timesteps, features)', y.shape)
# Out:
# ['left', 'right']
# (samples, timesteps, features) (74, 132, 7)
# (samples, timesteps, features) (76, 132, 7)

# %%
nsamples_r, nx_r, ny_r = x.shape
d2_x_r = x.reshape((nsamples_r,nx_r*ny_r))

nsamples_l, nx_l, ny_l = y.shape
d2_x_l = y.reshape((nsamples_l,nx_l*ny_l))

# %%
from sklearn.preprocessing import StandardScaler

scaler_r = StandardScaler()
scaler_r.fit(d2_x_r)
scaled_data_r = scaler_r.transform(d2_x_r)

scaler_l = StandardScaler()
scaler_l.fit(d2_x_l)
scaled_data_l = scaler_l.transform(d2_x_l)

# %%
scaled_data_r, scaled_data_l
# Out:
# (array([[-0.92125674, -0.6165565 , -0.69867153, ...,  0.1108021 ,
#          -1.26665914, -0.17671998],
#         [-1.29455354, -0.3242606 , -0.44893282, ..., -0.206346  ,
#          -0.59028727, -1.36097123],
#         [-0.85459138, -0.60811885, -0.7751116 , ..., -0.34795983,
#           0.28792832, -0.34046659],
#         ...,
#         [ 1.03513362, -0.76945603, -1.2987694 , ...,  0.65662284,
#           1.00996164,  0.90237715],
#         [ 1.908187  , -0.90759249, -0.6421859 , ...,  0.61504368,
#          -0.57523387, -1.39050083],
#         [ 1.03513362, -0.76945603, -1.2987694 , ...,  0.65662284,
#           1.00996164,  0.90237715]]),
#  array([[-1.46477018, -0.20442318, -0.54812896, ..., -0.91164057,
#           0.9355752 , -0.36047067],
#         [-0.71281781, -0.18970178, -1.05814794, ..., -1.05841284,
#           0.00642791, -0.82960431],
#         [-0.65617953,  0.08350756, -1.06507077, ..., -0.83919149,
#          -0.78679106,  0.41962511],
#         ...,
#         [ 0.93190884, -0.69714056, -0.61658057, ...,  0.80948324,
#          -1.69049941,  1.86122989],
#         [ 1.41998034, -1.01603191, -0.91500688, ...,  1.22256126,
#          -0.400035  , -0.18155669],
#         [ 0.93190884, -0.69714056, -0.61658057, ...,  0.80948324,
#          -1.69049941,  1.86122989]]))

# %%
scaled_data_r[:] = np.nan_to_num(scaled_data_r)
scaled_data_r

scaled_data_l[:] = np.nan_to_num(scaled_data_l)
scaled_data_l
# Out:
# array([[-1.46477018, -0.20442318, -0.54812896, ..., -0.91164057,
#          0.9355752 , -0.36047067],
#        [-0.71281781, -0.18970178, -1.05814794, ..., -1.05841284,
#          0.00642791, -0.82960431],
#        [-0.65617953,  0.08350756, -1.06507077, ..., -0.83919149,
#         -0.78679106,  0.41962511],
#        ...,
#        [ 0.93190884, -0.69714056, -0.61658057, ...,  0.80948324,
#         -1.69049941,  1.86122989],
#        [ 1.41998034, -1.01603191, -0.91500688, ...,  1.22256126,
#         -0.400035  , -0.18155669],
#        [ 0.93190884, -0.69714056, -0.61658057, ...,  0.80948324,
#         -1.69049941,  1.86122989]])

# %%
from sklearn.decomposition import PCA

components = min(74, 7)
pca_r = PCA(n_components=components, svd_solver='full')
pca_r.fit(scaled_data_r)
x_pca_r = pca_r.transform(scaled_data_r)
x_new_r = pca_r.inverse_transform(x_pca_r)
print("Original Shape:   ", scaled_data_r.shape)
print("Transformed Shape:", x_pca_r.shape)
# Out:
# Original Shape:    (74, 924)
# Transformed Shape: (74, 7)

# %%
components = min(76, 7)
pca_l = PCA(n_components=components, svd_solver='full')
pca_l.fit(scaled_data_l)
x_pca_l = pca_l.transform(scaled_data_l)
x_new_l = pca_l.inverse_transform(x_pca_l)
print("Original Shape:   ", scaled_data_l.shape)
print("Transformed Shape:", x_pca_l.shape)
# Out:
# Original Shape:    (76, 924)
# Transformed Shape: (76, 7)

# %%
fig, axs = plt.subplots(1, 2, figsize=(20,10))
axs[0].scatter(x_pca_r[:,0],x_pca_r[:,1])
axs[0].set_title('RIGHT')
axs[1].scatter(x_pca_l[:,0],x_pca_l[:,1])
axs[1].set_title('LEFT')
    
for ax in axs.flat:
    ax.set(xlabel='First principal component', ylabel='Second Principal Component')
        
for ax in axs.flat:
    ax.label_outer()

# %%
pca_r.components_
# Out:
# array([[-0.03381575,  0.02521248, -0.04130289, ..., -0.02624873,
#         -0.02324234, -0.02746097],
#        [-0.01037064,  0.00592032,  0.03051843, ..., -0.0054716 ,
#         -0.06709259, -0.02876125],
#        [ 0.05571567, -0.02164886, -0.00716857, ..., -0.04722896,
#          0.01671422,  0.04090932],
#        ...,
#        [ 0.02585634, -0.03965704, -0.04753449, ...,  0.02152786,
#         -0.0120642 ,  0.01693592],
#        [ 0.04163187,  0.03690088, -0.01559244, ..., -0.06942938,
#          0.00170635,  0.00348531],
#        [ 0.01776921,  0.04871863,  0.00316078, ...,  0.03464937,
#          0.01271066, -0.00716654]])

# %%
path = f'cut_one_gait_cycle_right'
filelist =[]
digits =[]
digits_int =[]
for file in glob.glob(f'{path}\\*.c3d',recursive = True):
    filelist.append(file[4:-4].replace("_", ""))
    digits.append(file[25:-9])

for ele in digits:
    digits_int.append(1) if ele=='degeneration' else digits_int
len(digits_int)
# Out:
# 41

# %%
# plt.figure(figsize=(10,10))
# plt.scatter(x_pca[:, 0], x_pca[:, 1],
#             c=digits_int, edgecolor='none', alpha=0.8,
#             cmap=plt.cm.get_cmap("Spectral", 2), s=56)
# plt.xlabel('component 1')
# plt.ylabel('component 2')
# plt.title("Principal Component Analysis of Human GAIT",fontsize=20)
# targets = ['degeneration', 'healthy']
# plt.colorbar();

# %%
fig, axs = plt.subplots(1, 2, figsize=(20,10))
axs[0].plot(x_pca_r[0:40,0],x_pca_r[0:40,1], 'o', markersize=7, color='blue', alpha=0.5, label='degeneration')
axs[0].plot(x_pca_r[41:74,0], x_pca_r[41:74,1], '^', markersize=7, color='red', alpha=0.5, label='healthy')
axs[0].legend()
axs[0].set_title('RIGHT')
axs[1].plot(x_pca_l[0:40,0],x_pca_l[0:40,1], 'o', markersize=7, color='blue', alpha=0.5, label='degeneration')
axs[1].plot(x_pca_l[41:76,0], x_pca_l[41:76,1], '^', markersize=7, color='red', alpha=0.5, label='healthy')
axs[1].legend()
axs[1].set_title('LEFT')

for ax in axs.flat:
    ax.set(xlabel='First principal component', ylabel='Second Principal Component')
        
for ax in axs.flat:
    ax.label_outer()

# %%
# plt.figure(figsize=(10,10))
# plt.plot(x_pca[0:36,0],x_pca[0:36,1], 'o', markersize=7, color='blue', alpha=0.5, label='degeneration')
# plt.plot(x_pca[37:56,0], x_pca[37:56,1], '^', markersize=7, color='red', alpha=0.5, label='healthy')
# plt.title("Principal Component Analysis of Human GAIT",fontsize=20)
# plt.legend()

# %%
features = ['jrd', 'jra', 'meanH', 'stdH', 'skewH', 'meanV', 'stdV']
features
# Out:
# ['jrd', 'jra', 'meanH', 'stdH', 'skewH', 'meanV', 'stdV']

# %%
map= pd.DataFrame(pd.DataFrame(x_pca_r),columns=features)
plt.figure(figsize=(19,8))
sns.heatmap(map,cmap='twilight')
# Out:
# <AxesSubplot:>

# %%
map= pd.DataFrame(x_pca_l,columns=features)
plt.figure(figsize=(19,8))
sns.heatmap(map,cmap='twilight')
# Out:
# <AxesSubplot:>

# %%
explained_variance_r = pca_r.explained_variance_ratio_
explained_variance_l = pca_l.explained_variance_ratio_

fig, axs = plt.subplots(1, 2, figsize=(10,5))
axs[0].plot(np.cumsum(explained_variance_r))
axs[0].grid()
axs[0].set_title('RIGHT')
axs[1].plot(np.cumsum(explained_variance_l))
axs[1].grid()
axs[1].set_title('LEFT')

for ax in axs.flat:
    ax.set(xlabel='number of components', ylabel='cumulative explained variance')
        
for ax in axs.flat:
    ax.label_outer()

# %%
print ( "Components = ", pca_r.n_components_ , ";\nTotal explained variances right/left = ",
      (explained_variance_r), (explained_variance_l)  )
# Out:
# Components =  7 ;
# Total explained variances right/left =  [0.2731627  0.1708293  0.10336603 0.09178    0.08122552 0.05122902
#  0.04577162] [0.25790919 0.14752815 0.11483308 0.09369968 0.07643063 0.06519182
#  0.04064156]

# %%
# Visualizing 4-D mix data using scatter plots
# leveraging the concepts of hue and depth
fig = plt.figure(figsize=(8, 6))
t = fig.suptitle('jrd - jra - hdf', fontsize=14)
ax = fig.add_subplot(111, projection='3d')

xs = list(x_pca_r[:,0])
ys = list(x_pca_r[:,1])
zs = list(x_pca_r[:,2])
ax.scatter(xs, ys, zs, s=50, alpha=0.6, edgecolors='w')

ax.set_xlabel('jra')
ax.set_ylabel('jrd')
ax.set_zlabel('hdf')
# Out:
# Text(0.5, 0, 'hdf')
